# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy.linalg
import random

path = "DataScience_salaries_2024.csv"

df = pd.read_csv(path, usecols=['job_title','experience_level'])
#df = pd.read_csv(path)
#df = df.dropna(axis=0, how='any')
df = df.drop_duplicates()
df
# Out:
#       experience_level                       job_title
# 0                   MI                  Data Scientist
# 1                   MI                 BI Data Analyst
# 3                   MI                     ML Engineer
# 4                   SE  Lead Machine Learning Engineer
# 6                   SE            Data Science Manager
# ...                ...                             ...
# 14751               EN          Data Analytics Manager
# 14800               EN           Data Quality Engineer
# 14818               EN         Data Analytics Engineer
# 14823               EN               Data Analyst Lead
# 14834               EX              Staff Data Analyst
#
# [334 rows x 2 columns]

# %%
# Chuyển đổi dataframe thành đồ thị
job_title = df['job_title']
experience_level = df['experience_level']
print("Số lượng ngành nghề:", job_title.nunique())
print("Số lượng mức độ kinh nghiệm:", experience_level.nunique())
print("Số cạnh", len(df))
# Out:
# Số lượng ngành nghề: 153
# Số lượng mức độ kinh nghiệm: 4
# Số cạnh 334

# %%
from networkx.algorithms import bipartite
B = nx.Graph()
for index, row in df.iterrows():
  B.add_edge(row['job_title'], row['experience_level'], weight=1)
B.add_nodes_from(job_title, bipartite=0)
B.add_nodes_from(experience_level, bipartite=1)

# %%
plt.figure(figsize=(15,15))
pos = nx.spring_layout(B, scale = 40)
fig, ax = plt.subplots(1,1, figsize=(6,6), dpi = 150)
nx.draw_networkx(B, pos = nx.drawing.layout.bipartite_layout(B, job_title), font_size=4, width=0.4, node_size=150)

# %%
from networkx.algorithms import bipartite
job_title = list(set(job_title))  # Loại bỏ các phần tử trùng lặp
G = bipartite.weighted_projected_graph(B, job_title)
plt.figure(figsize=(12, 12))

layout = nx.spring_layout(G)

# Vẽ các đỉnh
nx.draw_networkx_nodes(
    G,
    layout,
    nodelist=job_title,
    node_size=300,
    node_color='blue'
)

# Vẽ các cạnh
nx.draw_networkx_edges(G, layout, width=0.1, edge_color="#000000")

# Đặt nhãn cho các đỉnh
node_labels = dict(zip(job_title, job_title))
nx.draw_networkx_labels(G, layout, labels=node_labels)

plt.axis('off')
plt.show()

# %%
#in đồ thị 1 phía ra file csv
labels = nx.get_edge_attributes(G,'weight')
data = [{'source': key[0], 'target': key[1], 'weight': value} for key, value in labels.items()]
df2 = pd.DataFrame(data)
df2.to_csv(r'dothi1phia_full.csv', index = False, header = True)

# %%
import networkx as nx
from community import community_louvain
import matplotlib.pyplot as plt

# Chạy thuật toán Louvain
partition = community_louvain.best_partition(G)

# Đếm số lượng màu sắc
num_colors = len(set(partition.values()))

# Vẽ đồ thị với màu sắc tương ứng với cộng đồng
pos = nx.spring_layout(G)
plt.figure(figsize=(18, 8))
colors = [partition[node] for node in G.nodes()]
nx.draw(G, pos=pos, node_color=colors, cmap='viridis',node_size=80, with_labels=True, font_size=6, width=1.0)

# Hiển thị số lượng màu
plt.text(0.5, -0.1, f"Số lượng màu: {num_colors}", transform=plt.gca().transAxes, ha="center")
#num_colors = min(len(set(partition.values())), 8)
# Hiển thị đồ thị
plt.show()

# %%
import numpy as np
values = list(partition.values())

#kt số lượng cộng đồng
print('số lượng cộng đồng: ', len(np.unique(values)))
# Out:
# số lượng cộng đồng:  4

# %%
import numpy as np
values = list(partition.values())
group = [[] for _ in range(len(np.unique(values)))]
for i in range (len(np.unique(values))):
  for name, k in partition.items():
    if k==i:
      group[i].append(name)
for data in group:
  print(data)
for i in range(len(np.unique(values))):
  value = group[i]
  filter_data = df[df['job_title'].isin(value)]
  #in ra file excel
  name = 'cum' + str(i) +'.xlsx'
  filter_data.to_excel(name, index=False)
# Out:
# ['Data Operations Associate', 'Data Integration Specialist', 'Computer Vision Engineer', 'Marketing Data Engineer', 'Applied Machine Learning Scientist', 'Applied Scientist', 'Admin & Data Analyst', 'Machine Learning Developer', 'Data Quality Analyst', 'AI Programmer', 'Business Intelligence Data Analyst', 'Data DevOps Engineer', 'Data Analyst Lead', 'Data Analytics Engineer', 'BI Data Engineer', 'Deep Learning Engineer', 'Quantitative Research Analyst', 'Business Data Analyst', 'Compliance Data Analyst', 'Data Management Analyst', 'Research Analyst', 'Data Operations Analyst', 'Research Engineer', 'Data Specialist', 'Machine Learning Research Engineer', 'Data Analytics Consultant', 'Data Integration Engineer', 'Machine Learning Operations Engineer', 'AI Research Engineer', 'Data Visualization Specialist', 'Big Data Engineer', 'Insight Analyst', 'Data Reporting Analyst', 'Applied Data Scientist', 'Computer Vision Software Engineer', 'Data Science Analyst', 'Financial Data Analyst', 'BI Analyst', 'MLOps Engineer', 'Product Data Analyst', 'Data Developer', 'Cloud Data Engineer', 'AI Developer']
# ['Principal Machine Learning Engineer', 'Data Visualization Engineer', 'Data Strategy Manager', 'Data Visualization Analyst', 'Cloud Data Architect', 'CRM Data Analyst', 'Deep Learning Researcher', 'Data Operations Manager', 'Data Analytics Specialist', 'Data Management Consultant', 'Staff Data Scientist', 'Principal Data Architect', 'Consultant Data Engineer', 'Data Integration Developer', 'Big Data Architect', 'Data Quality Engineer', 'Applied Research Scientist', 'Azure Data Engineer', 'Analytics Engineering Manager', 'Business Intelligence Lead', 'Finance Data Analyst', 'Principal Data Engineer', 'Manager Data Management', 'Computational Biologist', 'AI Software Engineer', 'Marketing Data Scientist', 'Staff Machine Learning Engineer', 'Machine Learning Manager', 'AI Research Scientist', 'Data Analytics Associate', 'Marketing Data Analyst', 'Machine Learning Modeler', 'Data Pipeline Engineer', 'Data Science Tech Lead', 'Lead Machine Learning Engineer']
# ['Data Architect', 'AI Architect', 'Research Scientist', 'Data Lead', 'Business Intelligence Developer', 'Principal Data Scientist', 'Data Analytics Manager', 'Data Science Manager', 'BI Developer', 'Managing Director Data Science', 'Applied Machine Learning Engineer', 'Head of Data', 'Data Manager', 'AI Engineer', 'Data Science Engineer', 'Data Scientist', 'Head of Data Science', 'Machine Learning Engineer', 'Data Science Consultant', 'ETL Engineer', 'Machine Learning Scientist', 'NLP Engineer', 'Data Engineer', 'Business Intelligence Engineer', 'Lead Data Engineer', 'Analytics Engineer', 'Business Intelligence Analyst', 'Data Science', 'Data Analyst', 'Data Science Director', 'ML Engineer', 'BI Data Analyst', 'Head of Machine Learning', 'Director of Data Science', 'Staff Data Analyst', 'Business Intelligence', 'AI Scientist']
# ['Power BI Developer', 'Data Product Manager', 'Data Product Owner', 'ETL Developer', 'Sales Data Analyst', 'Business Intelligence Manager', 'Data Quality Manager', 'Data Operations Engineer', 'Lead Data Scientist', 'Robotics Software Engineer', 'Software Data Engineer', 'Machine Learning Specialist', 'Data Analytics Lead', 'Encounter Data Management Professional', 'Machine Learning Infrastructure Engineer', 'Data Operations Specialist', 'Autonomous Vehicle Technician', 'Data Infrastructure Engineer', 'Business Intelligence Specialist', 'Decision Scientist', 'AI Product Manager', 'Data Science Lead', 'Data Strategist', 'Data Science Practitioner', 'Robotics Engineer', 'Machine Learning Software Engineer', 'Machine Learning Researcher', 'Data Management Specialist', 'AWS Data Architect', 'Prompt Engineer', 'Cloud Database Engineer', 'Principal Data Analyst', 'Big Data Developer', 'Data Scientist Lead', 'Lead Data Analyst', 'Data Modeler', 'Data Modeller', 'ML Ops Engineer']

# %%
from sklearn.cluster import KMeans
nodes = list(G.nodes())
edges = list(G.edges())
node_degree = [G.degree(node) for node in G.nodes()]
degree_x =[[degree] for degree in node_degree]
degree_kmeans = KMeans(n_clusters=4).fit(degree_x)
degree_labels = degree_kmeans.labels_
print(degree_kmeans)

print(len(nodes))
pos = nx.spring_layout(G)
for i in range(len(nodes)):
  node = nodes[i]
  color = degree_labels[i]
  nx.draw_networkx_nodes(G, pos, [node], node_color=plt.cm.tab10(color))
nx.draw_networkx_edges(G, pos, edgelist=edges, alpha=0.5, edge_color="hotpink", node_size=100)
plt.show()

groups = {}
for node, label in zip(nodes, degree_labels):
    if label not in groups:
        groups[label] = []
    groups[label].append(node)

print("Groups:")
for label, nodes in groups.items():
    print("Group", label + 1, ":", nodes)
    value = nodes
    filter_data = df[df['job_title'].isin(value)]
    name = 'nhom' + str(label) +'.xlsx'
    filter_data.to_excel(name, index=False)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:433: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   node_collection = ax.scatter(
# KMeans(n_clusters=4)
# 153
# Groups:
# Group 1 : ['Data Architect', 'AI Architect', 'Research Scientist', 'Data Lead', 'Business Intelligence Developer', 'Data Product Manager', 'Data Integration Specialist', 'Principal Data Scientist', 'Data Analytics Manager', 'Computer Vision Engineer', 'Data Science Manager', 'BI Developer', 'ETL Developer', 'Applied Machine Learning Scientist', 'Applied Scientist', 'Admin & Data Analyst', 'Head of Data', 'Data Manager', 'Machine Learning Developer', 'AI Engineer', 'Business Intelligence Manager', 'Data Science Engineer', 'Data Quality Analyst', 'Data Analytics Specialist', 'Data Scientist', 'AI Programmer', 'Data DevOps Engineer', 'Data Operations Engineer', 'Lead Data Scientist', 'Robotics Software Engineer', 'Software Data Engineer', 'Data Analytics Engineer', 'Data Analytics Lead', 'Deep Learning Engineer', 'Machine Learning Infrastructure Engineer', 'Data Operations Specialist', 'Business Data Analyst', 'Data Infrastructure Engineer', 'Business Intelligence Specialist', 'Decision Scientist', 'AI Product Manager', 'Machine Learning Engineer', 'Data Science Lead', 'Data Science Consultant', 'Research Analyst', 'Machine Learning Scientist', 'Data Strategist', 'Data Operations Analyst', 'NLP Engineer', 'Research Engineer', 'Data Quality Engineer', 'Data Science Practitioner', 'Data Specialist', 'Data Engineer', 'Robotics Engineer', 'Azure Data Engineer', 'Business Intelligence Engineer', 'Lead Data Engineer', 'Analytics Engineer', 'Business Intelligence Analyst', 'Machine Learning Software Engineer', 'Data Integration Engineer', 'Machine Learning Operations Engineer', 'Finance Data Analyst', 'Data Visualization Specialist', 'Machine Learning Researcher', 'Data Management Specialist', 'Big Data Engineer', 'Prompt Engineer', 'Cloud Database Engineer', 'Applied Data Scientist', 'Computer Vision Software Engineer', 'Data Science', 'Data Analyst', 'ML Engineer', 'BI Data Analyst', 'AI Research Scientist', 'BI Analyst', 'Principal Data Analyst', 'MLOps Engineer', 'Product Data Analyst', 'Director of Data Science', 'Data Scientist Lead', 'Data Developer', 'Lead Data Analyst', 'Business Intelligence', 'Data Modeler', 'AI Scientist', 'Cloud Data Engineer', 'AI Developer']
# Group 2 : ['Power BI Developer', 'Principal Machine Learning Engineer', 'Data Visualization Engineer', 'Data Operations Associate', 'Data Product Owner', 'Data Strategy Manager', 'Data Visualization Analyst', 'Cloud Data Architect', 'CRM Data Analyst', 'Sales Data Analyst', 'Applied Machine Learning Engineer', 'Deep Learning Researcher', 'Data Operations Manager', 'Data Quality Manager', 'Business Intelligence Data Analyst', 'Data Management Consultant', 'Data Analyst Lead', 'Staff Data Scientist', 'Head of Data Science', 'Machine Learning Specialist', 'Encounter Data Management Professional', 'Principal Data Architect', 'Autonomous Vehicle Technician', 'Consultant Data Engineer', 'Data Management Analyst', 'Data Integration Developer', 'ETL Engineer', 'Big Data Architect', 'Applied Research Scientist', 'Analytics Engineering Manager', 'Business Intelligence Lead', 'Machine Learning Research Engineer', 'Data Analytics Consultant', 'AI Research Engineer', 'Principal Data Engineer', 'Manager Data Management', 'Computational Biologist', 'AI Software Engineer', 'AWS Data Architect', 'Insight Analyst', 'Marketing Data Scientist', 'Staff Machine Learning Engineer', 'Machine Learning Manager', 'Financial Data Analyst', 'Data Analytics Associate', 'Marketing Data Analyst', 'Machine Learning Modeler', 'Data Pipeline Engineer', 'Data Science Tech Lead', 'Big Data Developer', 'Staff Data Analyst', 'Data Modeller', 'Lead Machine Learning Engineer', 'ML Ops Engineer']
# Group 4 : ['Marketing Data Engineer', 'BI Data Engineer', 'Quantitative Research Analyst', 'Compliance Data Analyst', 'Data Reporting Analyst', 'Data Science Analyst']
# Group 3 : ['Managing Director Data Science', 'Data Science Director', 'Head of Machine Learning']
